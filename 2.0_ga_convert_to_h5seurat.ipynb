# %% [markdown]
# ### Convert Garcia-Alonso et al, Nat. Gen., 2021

# %%
suppressPackageStartupMessages({
    library(Seurat)
    library(SeuratDisk)
    library(SeuratObject)
    library(anndata)
    #library(ggplot2)
    #library(Matrix.stats)
})
options(warn=-1)

setwd("/work3/SingleCell/Arima")
options(stringsAsFactors = F)

# %%
# Convert all endometrium h5ad object into Seurat h5
Convert("data/ga_vv/processed/endometrium_all.h5ad", dest = "data/ga_vv/processed/ga_vv.h5seurat", overwrite = TRUE)
# Out:
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as data
#
# Adding raw/X as counts
#
# Adding meta.features from raw/var
#
# Adding X_umap_scvi_sampl_cc as cell embeddings for umap_scvi_sampl_cc
#
# Adding Binary Stage_colors to miscellaneous data
#
# Adding BinaryStage_colors to miscellaneous data
#
# Adding BiopsyType_colors to miscellaneous data
#
# Adding Broad cell type_colors to miscellaneous data
#
# Adding Cell type_colors to miscellaneous data
#
# Adding CellCycle Phase_colors to miscellaneous data
#
# Adding Day_colors to miscellaneous data
#
# Adding DonorID_colors to miscellaneous data
#
# Adding Location_colors to miscellaneous data
#
# Adding SampleID_colors to miscellaneous data
#
# Adding cosine_logXformedproj_bulkorg_colors to miscellaneous data
#
# Adding cosine_logXformedproj_bulkorg_hormnoinhib_colors to miscellaneous data
#
# Adding cosine_logXformedproj_bulkorg_hormnoinhib_res2_colors to miscellaneous data
#
# ...

# %% [raw]
# This process doesn't work well for this endometrial epithelial data
# # Convert all endometrium h5ad object into Seurat h5
# #Convert("data/endometrium_epithelial.h5ad", dest = "h5seurat", overwrite = TRUE)

# %%
# Convert endometrium organoid h5ad object into Seurat h5
Convert("data/ga_org/processed/endometrium_organoid.h5ad", dest = "data/ga_org/processed/ga_org.h5seurat", overwrite = TRUE)
# Out:
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as data
#
# Adding raw/X as counts
#
# Adding meta.features from raw/var
#
# Adding X_umap as cell embeddings for umap
#
# Adding X_umap_without_inhibitors as cell embeddings for umap_without_inhibitors
#
# Adding CellCycle Phase_colors to miscellaneous data
#
# Adding Celltype_colors to miscellaneous data
#
# Adding Celltype_without_inhibitors_colors to miscellaneous data
#
# Adding Days_colors to miscellaneous data
#
# Adding Hormones_colors to miscellaneous data
#
# Adding Inhibitor_colors to miscellaneous data

# %%
sessionInfo()
# Out:
# R version 4.2.2 Patched (2022-11-10 r83330)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.5 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/atlas/libblas.so.3.10.3
# LAPACK: /usr/lib/x86_64-linux-gnu/atlas/liblapack.so.3.10.3
#
# locale:
#  [1] LC_CTYPE=C.UTF-8       LC_NUMERIC=C           LC_TIME=C.UTF-8
#  [4] LC_COLLATE=C.UTF-8     LC_MONETARY=C.UTF-8    LC_MESSAGES=C.UTF-8
#  [7] LC_PAPER=C.UTF-8       LC_NAME=C              LC_ADDRESS=C
# [10] LC_TELEPHONE=C         LC_MEASUREMENT=C.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] anndata_0.7.5.5       SeuratDisk_0.0.0.9020 SeuratObject_4.1.3
# [4] Seurat_4.3.0
#
# loaded via a namespace (and not attached):
#   [1] Rtsne_0.16             colorspace_2.1-0       deldir_1.0-6
#   [4] ellipsis_0.3.2         ggridges_0.5.4         IRdisplay_1.1
# ...
